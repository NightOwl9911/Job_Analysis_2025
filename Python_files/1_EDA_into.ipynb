# %% [markdown]
# ## Importing and cleaning information for the analysis

# %%
# Importing Libraries
import ast # To convert the skils to a list
import pandas as pd 
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data (Job postings)
df = pd.read_csv(r"C:\Users\WIN10\Desktop\Job_Analysis_2025\Job_CSV\jobs_postings.csv")


# Data clean up
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# Create the column month (data will be analyzed monthly)

df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

# Filter by the year and sorting by month
df_2025 = df[df['job_posted_date'].dt.year == 2025].copy()
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

df_2025['job_posted_month'] = pd.Categorical(
    df_2025['job_posted_month'],
    categories=month_order,
    ordered=True
)

# %% [markdown]
# ## Filtering by Jobs Analyst Roles in Colombia

# %%
# Get dataframe for Colombian jobs in 2025 filter by Data roles

# Data Analyst
df_da_col = df_2025[(df_2025['job_country'] == 'Colombia') & (df_2025['job_title_short'] == 'Data Analyst')]

# Data Scientist
df_ds_col = df_2025[(df_2025['job_country'] == 'Colombia') & (df_2025['job_title_short'] == 'Data Scientist')]

# %% [markdown]
# ### Finding the locations in Colombia with the most offers for Data Analysts

# %%
# Getting top locations in colombia based on job postings

df_plot_da = (df_da_col.loc[df_da_col['job_location'] != 'Colombia', 'job_location'] # Remove the data that only shows Colombia as we want the specific location
           .value_counts()
           .rename(index={
               'Bogotá, Bogota, Colombia':'Bogotá, D.C.',
               'Medellín, Medellin, Antioquia, Colombia':'Medellín, Antioquia',
               'Colombia, Huila, Colombia' : 'Huila',
               'Girardot, Cundinamarca, Colombia' : ' Girardot, Cundinamarca',
               'Cali, Valle del Cauca, Colombia' : 'Cali, Valle del Cauca',
               'Sevilla, Valle del Cauca, Colombia' : 'Sevilla, Valle del Cauca',
               'San Vicente, Antioquia, Colombia' : 'San Vicente, Antioquia',
               'Manizales, Caldas, Colombia' : 'Manizales, Caldas',
               'Pamplona, North Santander, Colombia' : 'Pamplona, Norte de Santander'})
           .head(10)
           .to_frame())

dark_palette = [
    "#4cc9f0",  # cyan
    "#f72585",  # pink
    "#b8f2e6",  # mint
    "#ffd166",  # yellow
    "#90dbf4",  # sky
    "#cdb4db",  # lavender
    "#a7c957",  # lime
    "#ff9f1c",  # orange
    "#2ec4b6",  # teal
    "#e71d36"   # red
]

# Plotting the information
fig, ax = plt.subplots(figsize=(8, 6))
# Background
fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#1e1e1e')

# Styling
sns.set_theme(style='ticks')
sns.despine()
sns.barplot(data=df_plot_da, x='count', y='job_location', hue='count', palette=dark_palette, ax=ax)
plt.ylabel('Count', color='white')
plt.xlabel('')
plt.title('Top locations in Colombia for Data Analyst', color='white')
plt.xticks(color='white')
plt.yticks(color='white')
ax.set_ylabel('')
ax.set_xlabel('Postings Amount', color='white')
plt.legend(title='--Count--')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], title='--Count--')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Finding the locations in Colombia with the most offers for Data Scientists

# %%
# Getting top locations in colombia based on job postings

df_plot_ds = (df_ds_col.loc[df_ds_col['job_location'] != 'Colombia', 'job_location'] # Remove the data that only shows Colombia as we want the specific location
              .value_counts()
              .rename(index={
               'Bogotá, Bogota, Colombia':'Bogotá, D.C.',
               'Medellín, Medellin, Antioquia, Colombia':'Medellín, Antioquia',
               'Colombia, Huila, Colombia' : 'Huila',
               'Bucaramanga, Santander, Colombia' : 'Bucaramanga, Santander',
               'Cali, Valle del Cauca, Colombia' : 'Cali, Valle del Cauca',
               'Sevilla, Valle del Cauca, Colombia' : 'Sevilla, Valle del Cauca',
               'San Vicente, Antioquia, Colombia' : 'San Vicente, Antioquia',
               'Manizales, Caldas, Colombia' : 'Manizales, Caldas',
               'Bello, Antioquia, Colombia' : 'Bello, Antioquia'})
              .head(10)
              .to_frame())


dark_palette = [
    "#4cc9f0",  # cyan
    "#f72585",  # pink
    "#b8f2e6",  # mint
    "#ffd166",  # yellow
    "#90dbf4",  # sky
    "#cdb4db",  # lavender
    "#a7c957",  # lime
    "#ff9f1c",  # orange
    "#2ec4b6",  # teal
    "#e71d36"   # red
]

# Plotting the information
fig, ax = plt.subplots(figsize=(8, 6))
# Background
fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#1e1e1e')

# Styling
sns.despine()
sns.barplot(data=df_plot_ds, x='count', y='job_location', hue='count', palette=dark_palette, ax=ax)
plt.ylabel('Count', color='white')
plt.xlabel('')
plt.title('Top locations in Colombia for Data Scientist', color='white')
plt.xticks(color='white')
ax.set_ylabel('')
ax.set_xlabel('Postings Amount', color='white')
plt.yticks(color='white')
plt.legend(title='--Count--')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], title='--Count--')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Checking the availability for remote jobs and the ones requesting a degree for Data Analysts

# %%
# Format the titles of the pie charts

pie_colums = {
    'job_work_from_home' : 'Work from Home Offered DA',
    'job_no_degree_mention' : 'No Degree Requirement DA',
}

colors = [sns.color_palette('RdBu'),sns.color_palette('vlag')]

# Plotting
fig, ax = plt.subplots(1, 2, figsize=(10,6))

# Background
fig.patch.set_facecolor('black')

# Plotting the different pie charts
for i, (column, title) in enumerate(pie_colums.items()):
    ax[i].pie(df_da_col[column].value_counts(), labels=['No', 'Yes'], colors=colors[i], autopct='%1.2f%%', startangle=90, textprops={'color':'white'}, wedgeprops={'edgecolor':'grey'})
    ax[i].set_title(title, color='white')
    ax[i].tick_params(colors='white')
    

plt.show()

# %% [markdown]
# ### Checking the availability for remote jobs and the ones requesting a degree for Data Scientists

# %%
# Format the titles of the pie charts

pie_colums = {
    'job_work_from_home' : 'Work from Home Offered DS',
    'job_no_degree_mention' : 'No Degree Requirement DS',
}

colors = [sns.color_palette('RdBu'),sns.color_palette('vlag')]

# Plotting
fig, ax = plt.subplots(1, 2, figsize=(10,6))

# Background
fig.patch.set_facecolor('black')

# Plotting the different pie charts
for i, (column, title) in enumerate(pie_colums.items()):
    ax[i].pie(df_ds_col[column].value_counts(), labels=['No', 'Yes'], colors=colors[i], autopct='%1.2f%%', startangle=90, textprops={'color':'white'}, wedgeprops={'edgecolor':'grey'})
    ax[i].set_title(title, color='white')
    ax[i].tick_params(colors='white')
    

plt.show()

# %% [markdown]
# ### Finding the companies with the most offers for Data Analysts

# %%
# Getting top locations in colombia based on job postings

df_plot_da_com = df_da_col['company_name'].value_counts().head(10).to_frame()


# Plotting the information
fig, ax = plt.subplots(figsize=(8, 6))
# Background
fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#1e1e1e')

# Styling
sns.despine()
sns.barplot(data=df_plot_da_com, x='count', y='company_name', hue='count', palette='vlag', ax=ax)
plt.ylabel('Count', color='white')
plt.xlabel('')
plt.title('Top Companies in Colombia for Data Analyst', color='white')
plt.xticks(color='white')
ax.set_ylabel('')
plt.yticks(color='white')
plt.legend(title='--Count--')
ax.set_xlabel('Offers amount', color='white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], title='--Count--')



plt.show()

# %% [markdown]
# ### Finding the companies with the most offers for Data Scientists

# %%
# Getting top locations in colombia based on job postings

df_plot_ds_com = df_ds_col['company_name'].value_counts().head(10).to_frame()


# Plotting the information
fig, ax = plt.subplots(figsize=(8, 6))
# Background
fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#1e1e1e')

# Styling
sns.despine()
sns.barplot(data=df_plot_ds_com, x='count', y='company_name', hue='count', palette='vlag', ax=ax)
plt.ylabel('Count', color='white')
plt.xlabel('')
plt.title('Top Companies in Colombia for Data Scientist Offers', color='white')
plt.xticks(color='white')
ax.set_ylabel('')
ax.set_xlabel('Offers amount', color='white')
plt.yticks(color='white')
plt.legend(title='--Count--')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], title='--Count--')



plt.show()
